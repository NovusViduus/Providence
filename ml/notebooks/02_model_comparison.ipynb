# %% [markdown]
# # Model Comparison
#
# Side-by-side evaluation of Random Forest, XGBoost, and LightGBM on CICIDS2017.
# - Confusion matrices
# - Per-category F1 bar chart
# - Feature importance comparison
# - ROC curve overlay
# - Deployment recommendation

# %%
import sys
sys.path.insert(0, '..')

from src.models.model_registry import ModelRegistry
from src.data.cicids_loader import load_cicids
import numpy as np
import matplotlib.pyplot as plt

registry = ModelRegistry()
print('Available models:', registry.list_models())
